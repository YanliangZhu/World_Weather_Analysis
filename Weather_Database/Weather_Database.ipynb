# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 758

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

record_count = 1
set_count = 1

for i, city in enumerate(cities):
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    city_url = url + "&q=" + city.replace(" ","+")
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Date": city_date})

    except:
        print("City not found. Skipping...")
        pass

print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vaini
# Processing Record 2 of Set 1 | havelock
# Processing Record 3 of Set 1 | mount isa
# Processing Record 4 of Set 1 | santa maria da boa vista
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | saldanha
# Processing Record 8 of Set 1 | akureyri
# Processing Record 9 of Set 1 | henties bay
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | hermanus
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | langham
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | bagotville
# Processing Record 17 of Set 1 | saint-georges
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | nuuk
# Processing Record 21 of Set 1 | pattani
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | antalaha
# Processing Record 24 of Set 1 | hilo
# Processing Record 25 of Set 1 | nikel
# Processing Record 26 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 27 of Set 1 | saskylakh
# Processing Record 28 of Set 1 | gamba
# Processing Record 29 of Set 1 | kysyl-syr
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | port-cartier
# Processing Record 32 of Set 1 | korla
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | hiroshima
# Processing Record 35 of Set 1 | praia da vitoria
# Processing Record 36 of Set 1 | sao filipe
# Processing Record 37 of Set 1 | straumen
# Processing Record 38 of Set 1 | teknaf
# Processing Record 39 of Set 1 | sur
# Processing Record 40 of Set 1 | ponta do sol
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | nome
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | luderitz
# Processing Record 45 of Set 1 | gariaband
# Processing Record 46 of Set 1 | palmer
# Processing Record 47 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | muros
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | bubaque
# Processing Record 2 of Set 2 | makakilo city
# Processing Record 3 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | talnakh
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | saint-pierre
# Processing Record 8 of Set 2 | salalah
# Processing Record 9 of Set 2 | mazurivka
# Processing Record 10 of Set 2 | bluff
# Processing Record 11 of Set 2 | port alfred
# Processing Record 12 of Set 2 | oriximina
# Processing Record 13 of Set 2 | bathsheba
# Processing Record 14 of Set 2 | businga
# Processing Record 15 of Set 2 | honningsvag
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | port elizabeth
# Processing Record 19 of Set 2 | sompeta
# Processing Record 20 of Set 2 | fergus falls
# Processing Record 21 of Set 2 | russell
# Processing Record 22 of Set 2 | narsaq
# Processing Record 23 of Set 2 | aquiraz
# Processing Record 24 of Set 2 | iracoubo
# Processing Record 25 of Set 2 | sao joao da barra
# Processing Record 26 of Set 2 | krasnoselkup
# Processing Record 27 of Set 2 | dauriya
# Processing Record 28 of Set 2 | allen
# Processing Record 29 of Set 2 | chuy
# Processing Record 30 of Set 2 | ler
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | amarante do maranhao
# Processing Record 33 of Set 2 | geraldton
# Processing Record 34 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 2 | bredasdorp
# Processing Record 36 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 38 of Set 2 | lumphat
# Processing Record 39 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 40 of Set 2 | rio gallegos
# Processing Record 41 of Set 2 | victoria
# Processing Record 42 of Set 2 | aban
# Processing Record 43 of Set 2 | villamar
# Processing Record 44 of Set 2 | bengkulu
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | vila velha
# Processing Record 47 of Set 2 | hasaki
# Processing Record 48 of Set 2 | bulawayo
# Processing Record 49 of Set 2 | maramba
# Processing Record 50 of Set 2 | hithadhoo
# Processing Record 1 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 3 | soligalich
# Processing Record 4 of Set 3 | baie-comeau
# Processing Record 5 of Set 3 | mbala
# Processing Record 6 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 3 | marzuq
# Processing Record 8 of Set 3 | bhatkal
# Processing Record 9 of Set 3 | charthawal
# Processing Record 10 of Set 3 | pevek
# Processing Record 11 of Set 3 | codrington
# Processing Record 12 of Set 3 | jining
# Processing Record 13 of Set 3 | abnub
# Processing Record 14 of Set 3 | buloh kasap
# Processing Record 15 of Set 3 | bagdarin
# Processing Record 16 of Set 3 | mana
# Processing Record 17 of Set 3 | maromitsa
# Processing Record 18 of Set 3 | broken hill
# Processing Record 19 of Set 3 | bethel
# Processing Record 20 of Set 3 | mansa
# Processing Record 21 of Set 3 | avarua
# Processing Record 22 of Set 3 | port victoria
# Processing Record 23 of Set 3 | kirakira
# Processing Record 24 of Set 3 | cidreira
# Processing Record 25 of Set 3 | chifeng
# Processing Record 26 of Set 3 | gallup
# Processing Record 27 of Set 3 | clyde river
# Processing Record 28 of Set 3 | casper
# Processing Record 29 of Set 3 | fairbanks
# Processing Record 30 of Set 3 | hamilton
# Processing Record 31 of Set 3 | lavrentiya
# Processing Record 32 of Set 3 | sibolga
# Processing Record 33 of Set 3 | moose factory
# Processing Record 34 of Set 3 | cayeli
# Processing Record 35 of Set 3 | portland
# Processing Record 36 of Set 3 | tuatapere
# Processing Record 37 of Set 3 | kikwit
# Processing Record 38 of Set 3 | ribeira grande
# Processing Record 39 of Set 3 | pangnirtung
# Processing Record 40 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 3 | havre-saint-pierre
# Processing Record 42 of Set 3 | antofagasta
# Processing Record 43 of Set 3 | springfield
# Processing Record 44 of Set 3 | fukue
# Processing Record 45 of Set 3 | bashtanka
# Processing Record 46 of Set 3 | bolotnoye
# Processing Record 47 of Set 3 | mnogovershinnyy
# Processing Record 48 of Set 3 | cayenne
# Processing Record 49 of Set 3 | east london
# Processing Record 50 of Set 3 | lorengau
# Processing Record 1 of Set 4 | opuwo
# Processing Record 2 of Set 4 | cherskiy
# Processing Record 3 of Set 4 | mar del plata
# Processing Record 4 of Set 4 | dunedin
# Processing Record 5 of Set 4 | sadovoye
# Processing Record 6 of Set 4 | morondava
# Processing Record 7 of Set 4 | muisne
# Processing Record 8 of Set 4 | prince george
# Processing Record 9 of Set 4 | kapaa
# Processing Record 10 of Set 4 | pisco
# Processing Record 11 of Set 4 | the valley
# Processing Record 12 of Set 4 | hofn
# Processing Record 13 of Set 4 | saint andrews
# Processing Record 14 of Set 4 | katsuura
# Processing Record 15 of Set 4 | gayeri
# Processing Record 16 of Set 4 | alofi
# Processing Record 17 of Set 4 | san luis
# Processing Record 18 of Set 4 | roebourne
# Processing Record 19 of Set 4 | nikolskoye
# Processing Record 20 of Set 4 | walvis bay
# Processing Record 21 of Set 4 | kavieng
# Processing Record 22 of Set 4 | isangel
# Processing Record 23 of Set 4 | padang
# Processing Record 24 of Set 4 | leh
# Processing Record 25 of Set 4 | severnoye
# Processing Record 26 of Set 4 | tikalaan
# City not found. Skipping...
# Processing Record 27 of Set 4 | aklavik
# Processing Record 28 of Set 4 | hami
# Processing Record 29 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 4 | kadoma
# Processing Record 31 of Set 4 | cape town
# Processing Record 32 of Set 4 | jamestown
# Processing Record 33 of Set 4 | upernavik
# Processing Record 34 of Set 4 | grajau
# Processing Record 35 of Set 4 | agdas
# Processing Record 36 of Set 4 | kropotkin
# Processing Record 37 of Set 4 | rypefjord
# Processing Record 38 of Set 4 | sarahan
# Processing Record 39 of Set 4 | harper
# Processing Record 40 of Set 4 | den helder
# Processing Record 41 of Set 4 | sept-iles
# Processing Record 42 of Set 4 | mwinilunga
# Processing Record 43 of Set 4 | udachnyy
# Processing Record 44 of Set 4 | tay ninh
# Processing Record 45 of Set 4 | san patricio
# Processing Record 46 of Set 4 | raga
# Processing Record 47 of Set 4 | klaksvik
# Processing Record 48 of Set 4 | georgetown
# Processing Record 49 of Set 4 | tiksi
# Processing Record 50 of Set 4 | sabha
# Processing Record 1 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 2 of Set 5 | san cristobal
# Processing Record 3 of Set 5 | bilibino
# Processing Record 4 of Set 5 | rawson
# Processing Record 5 of Set 5 | coihaique
# Processing Record 6 of Set 5 | ulladulla
# Processing Record 7 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 8 of Set 5 | skibbereen
# Processing Record 9 of Set 5 | puma
# Processing Record 10 of Set 5 | chazuta
# Processing Record 11 of Set 5 | dikson
# Processing Record 12 of Set 5 | sitka
# Processing Record 13 of Set 5 | jacksonville
# Processing Record 14 of Set 5 | karratha
# Processing Record 15 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 16 of Set 5 | saint-philippe
# Processing Record 17 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 5 | sechura
# Processing Record 19 of Set 5 | nhulunbuy
# Processing Record 20 of Set 5 | mahajanga
# Processing Record 21 of Set 5 | new norfolk
# Processing Record 22 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 23 of Set 5 | coahuayana
# Processing Record 24 of Set 5 | najran
# Processing Record 25 of Set 5 | hambantota
# Processing Record 26 of Set 5 | fortuna
# Processing Record 27 of Set 5 | norman wells
# Processing Record 28 of Set 5 | constitucion
# Processing Record 29 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 30 of Set 5 | romitan
# Processing Record 31 of Set 5 | saint-joseph
# Processing Record 32 of Set 5 | cochrane
# Processing Record 33 of Set 5 | port blair
# Processing Record 34 of Set 5 | santa maria
# Processing Record 35 of Set 5 | yaan
# Processing Record 36 of Set 5 | ponferrada
# Processing Record 37 of Set 5 | nerchinskiy zavod
# Processing Record 38 of Set 5 | savannah bight
# Processing Record 39 of Set 5 | voh
# Processing Record 40 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 41 of Set 5 | liling
# Processing Record 42 of Set 5 | livramento
# Processing Record 43 of Set 5 | san blas
# Processing Record 44 of Set 5 | mingguang
# Processing Record 45 of Set 5 | matagami
# Processing Record 46 of Set 5 | trelew
# Processing Record 47 of Set 5 | charters towers
# Processing Record 48 of Set 5 | kargat
# Processing Record 49 of Set 5 | whitehorse
# Processing Record 50 of Set 5 | charleville-mezieres
# Processing Record 1 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 2 of Set 6 | lodwar
# Processing Record 3 of Set 6 | mae sai
# Processing Record 4 of Set 6 | cabo san lucas
# Processing Record 5 of Set 6 | ansbach
# Processing Record 6 of Set 6 | zhanakorgan
# Processing Record 7 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 8 of Set 6 | ilulissat
# Processing Record 9 of Set 6 | alamogordo
# Processing Record 10 of Set 6 | astoria
# Processing Record 11 of Set 6 | mallama
# City not found. Skipping...
# Processing Record 12 of Set 6 | poum
# Processing Record 13 of Set 6 | half moon bay
# Processing Record 14 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 15 of Set 6 | disna
# Processing Record 16 of Set 6 | tir pol
# City not found. Skipping...
# Processing Record 17 of Set 6 | bida
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | barrow
# Processing Record 20 of Set 6 | kiunga
# Processing Record 21 of Set 6 | kankakee
# Processing Record 22 of Set 6 | puerto parra
# Processing Record 23 of Set 6 | bonfim
# Processing Record 24 of Set 6 | lebu
# Processing Record 25 of Set 6 | vao
# Processing Record 26 of Set 6 | taltal
# Processing Record 27 of Set 6 | provideniya
# Processing Record 28 of Set 6 | namatanai
# Processing Record 29 of Set 6 | omutinskoye
# City not found. Skipping...
# Processing Record 30 of Set 6 | saint-paul
# Processing Record 31 of Set 6 | irbeyskoye
# Processing Record 32 of Set 6 | trinidad
# Processing Record 33 of Set 6 | price
# Processing Record 34 of Set 6 | tual
# Processing Record 35 of Set 6 | andra
# Processing Record 36 of Set 6 | agirish
# Processing Record 37 of Set 6 | chichawatni
# Processing Record 38 of Set 6 | aksarka
# Processing Record 39 of Set 6 | rio das pedras
# Processing Record 40 of Set 6 | bonavista
# Processing Record 41 of Set 6 | tabat
# Processing Record 42 of Set 6 | smoky lake
# Processing Record 43 of Set 6 | kodiak
# Processing Record 44 of Set 6 | raudeberg
# Processing Record 45 of Set 6 | evensk
# Processing Record 46 of Set 6 | la tuque
# Processing Record 47 of Set 6 | griffith
# Processing Record 48 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 49 of Set 6 | mitsamiouli
# Processing Record 50 of Set 6 | pudozh
# Processing Record 1 of Set 7 | achisay
# City not found. Skipping...
# Processing Record 2 of Set 7 | itarema
# Processing Record 3 of Set 7 | barawe
# City not found. Skipping...
# Processing Record 4 of Set 7 | eureka
# Processing Record 5 of Set 7 | scarborough
# Processing Record 6 of Set 7 | sao felix do xingu
# Processing Record 7 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 8 of Set 7 | quilmana
# Processing Record 9 of Set 7 | faanui
# Processing Record 10 of Set 7 | oleksandrivka
# Processing Record 11 of Set 7 | manta
# Processing Record 12 of Set 7 | fort nelson
# Processing Record 13 of Set 7 | cervo
# Processing Record 14 of Set 7 | yulara
# Processing Record 15 of Set 7 | torbay
# Processing Record 16 of Set 7 | puerto santander
# Processing Record 17 of Set 7 | takoradi
# Processing Record 18 of Set 7 | vestmannaeyjar
# Processing Record 19 of Set 7 | lucapa
# Processing Record 20 of Set 7 | kruisfontein
# Processing Record 21 of Set 7 | carnarvon
# Processing Record 22 of Set 7 | sinnamary
# Processing Record 23 of Set 7 | novyy rogachik
# Processing Record 24 of Set 7 | cockburn town
# Processing Record 25 of Set 7 | rosetown
# Processing Record 26 of Set 7 | kloulklubed
# Processing Record 27 of Set 7 | sambava
# Processing Record 28 of Set 7 | khatanga
# Processing Record 29 of Set 7 | matadi
# Processing Record 30 of Set 7 | mafinga
# Processing Record 31 of Set 7 | batagay
# Processing Record 32 of Set 7 | nouadhibou
# Processing Record 33 of Set 7 | spasskoye
# Processing Record 34 of Set 7 | wojkowice
# Processing Record 35 of Set 7 | tilichiki
# Processing Record 36 of Set 7 | mont-de-marsan
# Processing Record 37 of Set 7 | ahumada
# City not found. Skipping...
# Processing Record 38 of Set 7 | oneida
# Processing Record 39 of Set 7 | miles city
# Processing Record 40 of Set 7 | komsomolskiy
# Processing Record 41 of Set 7 | vilya
# Processing Record 42 of Set 7 | makhachkala
# Processing Record 43 of Set 7 | tara
# Processing Record 44 of Set 7 | spassk-ryazanskiy
# Processing Record 45 of Set 7 | kaitangata
# Processing Record 46 of Set 7 | ayan
# Processing Record 47 of Set 7 | hoquiam
# Processing Record 48 of Set 7 | puerto suarez
# Processing Record 49 of Set 7 | valdivia
# Processing Record 50 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 1 of Set 8 | oktyabrskoye
# Processing Record 2 of Set 8 | aporawan
# City not found. Skipping...
# Processing Record 3 of Set 8 | san vicente
# Processing Record 4 of Set 8 | puerto escondido
# Processing Record 5 of Set 8 | port hedland
# Processing Record 6 of Set 8 | anderson
# Processing Record 7 of Set 8 | emerald
# Processing Record 8 of Set 8 | longyearbyen
# Processing Record 9 of Set 8 | bandarbeyla
# Processing Record 10 of Set 8 | basud
# Processing Record 11 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 8 | fasa
# Processing Record 13 of Set 8 | kibuye
# Processing Record 14 of Set 8 | swift current
# Processing Record 15 of Set 8 | yarada
# Processing Record 16 of Set 8 | yubari
# Processing Record 17 of Set 8 | ilhabela
# Processing Record 18 of Set 8 | high level
# Processing Record 19 of Set 8 | loa janan
# Processing Record 20 of Set 8 | boa vista
# Processing Record 21 of Set 8 | borzya
# Processing Record 22 of Set 8 | san borja
# Processing Record 23 of Set 8 | tupik
# Processing Record 24 of Set 8 | wiesloch
# Processing Record 25 of Set 8 | pacasmayo
# Processing Record 26 of Set 8 | dawei
# Processing Record 27 of Set 8 | touros
# Processing Record 28 of Set 8 | ryazan
# Processing Record 29 of Set 8 | iqaluit
# Processing Record 30 of Set 8 | jiangyou
# Processing Record 31 of Set 8 | mount gambier
# Processing Record 32 of Set 8 | ostersund
# Processing Record 33 of Set 8 | japura
# Processing Record 34 of Set 8 | camacha
# Processing Record 35 of Set 8 | derzhavinsk
# Processing Record 36 of Set 8 | mirai
# Processing Record 37 of Set 8 | mahenge
# Processing Record 38 of Set 8 | ostrovnoy
# Processing Record 39 of Set 8 | san ramon
# Processing Record 40 of Set 8 | besleney
# Processing Record 41 of Set 8 | lasa
# Processing Record 42 of Set 8 | santa rosa
# Processing Record 43 of Set 8 | baoying
# Processing Record 44 of Set 8 | chengde
# Processing Record 45 of Set 8 | linden
# Processing Record 46 of Set 8 | guozhen
# Processing Record 47 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 48 of Set 8 | olafsvik
# Processing Record 49 of Set 8 | kashi
# Processing Record 50 of Set 8 | beringovskiy
# Processing Record 1 of Set 9 | launceston
# Processing Record 2 of Set 9 | lompoc
# Processing Record 3 of Set 9 | port hardy
# Processing Record 4 of Set 9 | moron
# Processing Record 5 of Set 9 | manicore
# Processing Record 6 of Set 9 | bilma
# Processing Record 7 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 9 of Set 9 | am timan
# Processing Record 10 of Set 9 | cascais
# Processing Record 11 of Set 9 | almeirim
# Processing Record 12 of Set 9 | namibe
# Processing Record 13 of Set 9 | banyo
# Processing Record 14 of Set 9 | saint-augustin
# Processing Record 15 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 16 of Set 9 | pasighat
# Processing Record 17 of Set 9 | asaba
# Processing Record 18 of Set 9 | shancheng
# Processing Record 19 of Set 9 | morant bay
# Processing Record 20 of Set 9 | rosarito
# Processing Record 21 of Set 9 | sungaipenuh
# Processing Record 22 of Set 9 | tuxtepec
# Processing Record 23 of Set 9 | atbasar
# Processing Record 24 of Set 9 | meulaboh
# Processing Record 25 of Set 9 | ovsyanka
# Processing Record 26 of Set 9 | thompson
# Processing Record 27 of Set 9 | tautira
# Processing Record 28 of Set 9 | yumen
# Processing Record 29 of Set 9 | novyy urengoy
# Processing Record 30 of Set 9 | axim
# Processing Record 31 of Set 9 | abadiania
# Processing Record 32 of Set 9 | laguna
# Processing Record 33 of Set 9 | vila franca do campo
# Processing Record 34 of Set 9 | kralendijk
# Processing Record 35 of Set 9 | tombouctou
# Processing Record 36 of Set 9 | souillac
# Processing Record 37 of Set 9 | faya
# Processing Record 38 of Set 9 | dingle
# Processing Record 39 of Set 9 | ossora
# Processing Record 40 of Set 9 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 9 | pousat
# City not found. Skipping...
# Processing Record 42 of Set 9 | caravelas
# Processing Record 43 of Set 9 | garowe
# Processing Record 44 of Set 9 | strezhevoy
# Processing Record 45 of Set 9 | volksrust
# Processing Record 46 of Set 9 | knysna
# Processing Record 47 of Set 9 | daosa
# City not found. Skipping...
# Processing Record 48 of Set 9 | roald
# Processing Record 49 of Set 9 | funadhoo
# Processing Record 50 of Set 9 | altay
# Processing Record 1 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 2 of Set 10 | wairoa
# Processing Record 3 of Set 10 | san andres
# Processing Record 4 of Set 10 | rosetta
# Processing Record 5 of Set 10 | yerbogachen
# Processing Record 6 of Set 10 | nyrob
# Processing Record 7 of Set 10 | tres arroyos
# Processing Record 8 of Set 10 | amapa
# Processing Record 9 of Set 10 | martinsicuro
# Processing Record 10 of Set 10 | ixtapa
# Processing Record 11 of Set 10 | winslow
# Processing Record 12 of Set 10 | kenmare
# Processing Record 13 of Set 10 | kenai
# Processing Record 14 of Set 10 | mwanza
# Processing Record 15 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 10 | kupang
# Processing Record 17 of Set 10 | saint anthony
# Processing Record 18 of Set 10 | tevriz
# Processing Record 19 of Set 10 | clinton
# Processing Record 20 of Set 10 | ahuimanu
# Processing Record 21 of Set 10 | xanxere
# Processing Record 22 of Set 10 | ancud
# Processing Record 23 of Set 10 | la macarena
# Processing Record 24 of Set 10 | kamaishi
# Processing Record 25 of Set 10 | angoram
# Processing Record 26 of Set 10 | bambari
# Processing Record 27 of Set 10 | severo-kurilsk
# Processing Record 28 of Set 10 | chopinzinho
# Processing Record 29 of Set 10 | kuytun
# Processing Record 30 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 31 of Set 10 | uzumlu
# City not found. Skipping...
# Processing Record 32 of Set 10 | privolzhskiy
# Processing Record 33 of Set 10 | pionerskiy
# Processing Record 34 of Set 10 | mahebourg
# Processing Record 35 of Set 10 | ginda
# Processing Record 36 of Set 10 | taoudenni
# Processing Record 37 of Set 10 | biograd na moru
# Processing Record 38 of Set 10 | la ronge
# Processing Record 39 of Set 10 | pochutla
# Processing Record 40 of Set 10 | ipameri
# Processing Record 41 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 10 | porto velho
# Processing Record 43 of Set 10 | waingapu
# Processing Record 44 of Set 10 | puerto carreno
# Processing Record 45 of Set 10 | luganville
# Processing Record 46 of Set 10 | kodinsk
# Processing Record 47 of Set 10 | lhuntshi
# City not found. Skipping...
# Processing Record 48 of Set 10 | naze
# Processing Record 49 of Set 10 | college
# Processing Record 50 of Set 10 | porto novo
# Processing Record 1 of Set 11 | volovo
# Processing Record 2 of Set 11 | hualmay
# Processing Record 3 of Set 11 | orlik
# Processing Record 4 of Set 11 | cap malheureux
# Processing Record 5 of Set 11 | sioux lookout
# Processing Record 6 of Set 11 | edd
# Processing Record 7 of Set 11 | yarovoye
# Processing Record 8 of Set 11 | gizo
# Processing Record 9 of Set 11 | egvekinot
# Processing Record 10 of Set 11 | palafrugell
# Processing Record 11 of Set 11 | vanimo
# Processing Record 12 of Set 11 | guangyuan
# Processing Record 13 of Set 11 | locri
# Processing Record 14 of Set 11 | general roca
# Processing Record 15 of Set 11 | kibre mengist
# Processing Record 16 of Set 11 | sisimiut
# Processing Record 17 of Set 11 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 18 of Set 11 | ambilobe
# Processing Record 19 of Set 11 | marawi
# Processing Record 20 of Set 11 | marsa matruh
# Processing Record 21 of Set 11 | perth
# Processing Record 22 of Set 11 | grindavik
# Processing Record 23 of Set 11 | daru
# Processing Record 24 of Set 11 | vung tau
# Processing Record 25 of Set 11 | kendari
# Processing Record 26 of Set 11 | pryozerne
# Processing Record 27 of Set 11 | labuhan
# Processing Record 28 of Set 11 | mashhad
# Processing Record 29 of Set 11 | almaznyy
# Processing Record 30 of Set 11 | airai
# Processing Record 31 of Set 11 | baganga
# Processing Record 32 of Set 11 | sassandra
# Processing Record 33 of Set 11 | quelimane
# Processing Record 34 of Set 11 | lumding
# Processing Record 35 of Set 11 | uvinza
# Processing Record 36 of Set 11 | chibuto
# Processing Record 37 of Set 11 | cabra
# Processing Record 38 of Set 11 | pemba
# Processing Record 39 of Set 11 | oksfjord
# Processing Record 40 of Set 11 | buraydah
# Processing Record 41 of Set 11 | shache
# Processing Record 42 of Set 11 | valparaiso
# Processing Record 43 of Set 11 | barcelona
# Processing Record 44 of Set 11 | donskoye
# Processing Record 45 of Set 11 | milkovo
# Processing Record 46 of Set 11 | palu
# Processing Record 47 of Set 11 | matara
# Processing Record 48 of Set 11 | bairiki
# Processing Record 49 of Set 11 | rocha
# Processing Record 50 of Set 11 | narasapur
# Processing Record 1 of Set 12 | saurimo
# Processing Record 2 of Set 12 | bend
# Processing Record 3 of Set 12 | atar
# Processing Record 4 of Set 12 | birin
# Processing Record 5 of Set 12 | hobyo
# Processing Record 6 of Set 12 | torbat-e jam
# Processing Record 7 of Set 12 | xining
# Processing Record 8 of Set 12 | yining
# Processing Record 9 of Set 12 | silyanah
# City not found. Skipping...
# Processing Record 10 of Set 12 | palauig
# Processing Record 11 of Set 12 | priiskovyy
# Processing Record 12 of Set 12 | kushva
# Processing Record 13 of Set 12 | mehamn
# Processing Record 14 of Set 12 | khani
# Processing Record 15 of Set 12 | ola
# Processing Record 16 of Set 12 | asau
# Processing Record 17 of Set 12 | puerto leguizamo
# Processing Record 18 of Set 12 | chokurdakh
# Processing Record 19 of Set 12 | burica
# City not found. Skipping...
# Processing Record 20 of Set 12 | krasnorechenskiy
# Processing Record 21 of Set 12 | jennings
# Processing Record 22 of Set 12 | saquarema
# Processing Record 23 of Set 12 | cauquenes
# Processing Record 24 of Set 12 | margate
# Processing Record 25 of Set 12 | waddan
# Processing Record 26 of Set 12 | iquitos
# Processing Record 27 of Set 12 | freeport
# Processing Record 28 of Set 12 | bokspits
# City not found. Skipping...
# Processing Record 29 of Set 12 | bolshiye uki
# City not found. Skipping...
# Processing Record 30 of Set 12 | hokitika
# Processing Record 31 of Set 12 | kutum
# Processing Record 32 of Set 12 | biltine
# Processing Record 33 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 34 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 35 of Set 12 | arrifes
# Processing Record 36 of Set 12 | goderich
# Processing Record 37 of Set 12 | kambove
# Processing Record 38 of Set 12 | zhangye
# Processing Record 39 of Set 12 | mayo
# Processing Record 40 of Set 12 | yanji
# Processing Record 41 of Set 12 | kungurtug
# Processing Record 42 of Set 12 | hoi an
# Processing Record 43 of Set 12 | brownsburg
# Processing Record 44 of Set 12 | baruun-urt
# Processing Record 45 of Set 12 | espanola
# Processing Record 46 of Set 12 | misratah
# Processing Record 47 of Set 12 | nantucket
# Processing Record 48 of Set 12 | aripuana
# Processing Record 49 of Set 12 | tamandare
# Processing Record 50 of Set 12 | sangar
# Processing Record 1 of Set 13 | aswan
# Processing Record 2 of Set 13 | mecca
# Processing Record 3 of Set 13 | nkwerre
# Processing Record 4 of Set 13 | jacmel
# Processing Record 5 of Set 13 | qostanay
# Processing Record 6 of Set 13 | hillsborough
# Processing Record 7 of Set 13 | usinsk
# Processing Record 8 of Set 13 | itoman
# Processing Record 9 of Set 13 | praia
# Processing Record 10 of Set 13 | erenhot
# Processing Record 11 of Set 13 | nemuro
# Processing Record 12 of Set 13 | goma
# Processing Record 13 of Set 13 | tekeli
# Processing Record 14 of Set 13 | tromso
# Processing Record 15 of Set 13 | clarence town
# Processing Record 16 of Set 13 | dilla
# Processing Record 17 of Set 13 | alta floresta
# Processing Record 18 of Set 13 | ahipara
# Processing Record 19 of Set 13 | jiaxing
# Processing Record 20 of Set 13 | leningradskiy
# Processing Record 21 of Set 13 | samarai
# Processing Record 22 of Set 13 | corinto
# Processing Record 23 of Set 13 | severobaykalsk
# Processing Record 24 of Set 13 | aksha
# Processing Record 25 of Set 13 | charyshskoye
# Processing Record 26 of Set 13 | bousso
# Processing Record 27 of Set 13 | koupela
# Processing Record 28 of Set 13 | gazanjyk
# Processing Record 29 of Set 13 | ixtlan del rio
# Processing Record 30 of Set 13 | middelburg
# Processing Record 31 of Set 13 | namuac
# Processing Record 32 of Set 13 | tsabong
# Processing Record 33 of Set 13 | yar-sale
# Processing Record 34 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 13 | genhe
# Processing Record 36 of Set 13 | backo petrovo selo
# Processing Record 37 of Set 13 | upington
# Processing Record 38 of Set 13 | arman
# Processing Record 39 of Set 13 | guelavia
# City not found. Skipping...
# Processing Record 40 of Set 13 | itaituba
# Processing Record 41 of Set 13 | warrnambool
# Processing Record 42 of Set 13 | flinders
# Processing Record 43 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 13 | chkalovsk
# Processing Record 45 of Set 13 | kayerkan
# Processing Record 46 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 47 of Set 13 | ponta delgada
# Processing Record 48 of Set 13 | shingu
# Processing Record 49 of Set 13 | kleck
# City not found. Skipping...
# Processing Record 50 of Set 13 | aleksandrov gay
# Processing Record 1 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 2 of Set 14 | kununurra
# Processing Record 3 of Set 14 | honiara
# Processing Record 4 of Set 14 | visnes
# Processing Record 5 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 6 of Set 14 | rosario
# Processing Record 7 of Set 14 | coffs harbour
# Processing Record 8 of Set 14 | ilo
# Processing Record 9 of Set 14 | byron bay
# Processing Record 10 of Set 14 | gibsons
# Processing Record 11 of Set 14 | lakes entrance
# Processing Record 12 of Set 14 | nikolayevsk-na-amure
# Processing Record 13 of Set 14 | mrirt
# City not found. Skipping...
# Processing Record 14 of Set 14 | corona
# Processing Record 15 of Set 14 | francavilla fontana
# Processing Record 16 of Set 14 | montepuez
# Processing Record 17 of Set 14 | aykhal
# Processing Record 18 of Set 14 | jijiang
# Processing Record 19 of Set 14 | pallasovka
# Processing Record 20 of Set 14 | teya
# Processing Record 21 of Set 14 | reconquista
# Processing Record 22 of Set 14 | nobres
# Processing Record 23 of Set 14 | forio
# Processing Record 24 of Set 14 | hirado
# Processing Record 25 of Set 14 | mandalgovi
# Processing Record 26 of Set 14 | labrea
# Processing Record 27 of Set 14 | chiredzi
# Processing Record 28 of Set 14 | polunochnoye
# Processing Record 29 of Set 14 | mauriti
# Processing Record 30 of Set 14 | coquimbo
# Processing Record 31 of Set 14 | salta
# Processing Record 32 of Set 14 | tupancireta
# Processing Record 33 of Set 14 | inta
# Processing Record 34 of Set 14 | luanda
# Processing Record 35 of Set 14 | ronne
# Processing Record 36 of Set 14 | khorramabad
# Processing Record 37 of Set 14 | griffin
# Processing Record 38 of Set 14 | portlethen
# Processing Record 39 of Set 14 | hvammstangi
# City not found. Skipping...
# Processing Record 40 of Set 14 | pavlovsk
# Processing Record 41 of Set 14 | kaspiysk
# Processing Record 42 of Set 14 | adrar
# Processing Record 43 of Set 14 | le locle
# Processing Record 44 of Set 14 | salym
# Processing Record 45 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 46 of Set 14 | imeni poliny osipenko
# Processing Record 47 of Set 14 | bucerias
# Processing Record 48 of Set 14 | abu dhabi
# Processing Record 49 of Set 14 | wanaka
# Processing Record 50 of Set 14 | tecoanapa
# Processing Record 1 of Set 15 | kolhapur
# Processing Record 2 of Set 15 | sorland
# Processing Record 3 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 4 of Set 15 | winfield
# Processing Record 5 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 6 of Set 15 | kangaatsiaq
# Processing Record 7 of Set 15 | abu zabad
# Processing Record 8 of Set 15 | wajir
# Processing Record 9 of Set 15 | guhagar
# Processing Record 10 of Set 15 | ituporanga
# Processing Record 11 of Set 15 | dalbandin
# Processing Record 12 of Set 15 | dhanwar
# Processing Record 13 of Set 15 | hefei
# Processing Record 14 of Set 15 | odesskoye
# Processing Record 15 of Set 15 | mossendjo
# Processing Record 16 of Set 15 | vardo
# Processing Record 17 of Set 15 | dossor
# Processing Record 18 of Set 15 | semirom
# Processing Record 19 of Set 15 | port shepstone
# Processing Record 20 of Set 15 | farafangana
# Processing Record 21 of Set 15 | nokaneng
# Processing Record 22 of Set 15 | sakakah
# Processing Record 23 of Set 15 | verkhoyansk
# Processing Record 24 of Set 15 | talkha
# Processing Record 25 of Set 15 | grand-santi
# Processing Record 26 of Set 15 | road town
# Processing Record 27 of Set 15 | sayula
# Processing Record 28 of Set 15 | brae
# Processing Record 29 of Set 15 | berlevag
# Processing Record 30 of Set 15 | matay
# Processing Record 31 of Set 15 | elbistan
# Processing Record 32 of Set 15 | indiana
# Processing Record 33 of Set 15 | charleston
# Processing Record 34 of Set 15 | beloha
# Processing Record 35 of Set 15 | synya
# Processing Record 36 of Set 15 | dali
# Processing Record 37 of Set 15 | yavatmal
# Processing Record 38 of Set 15 | inirida
# Processing Record 39 of Set 15 | doka
# Processing Record 40 of Set 15 | srisailam
# Processing Record 41 of Set 15 | andenes
# Processing Record 42 of Set 15 | stanari
# Processing Record 43 of Set 15 | sola
# Processing Record 44 of Set 15 | qurayyat
# Processing Record 45 of Set 15 | kurchum
# Processing Record 46 of Set 15 | puerto del rosario
# Processing Record 47 of Set 15 | chikwawa
# Processing Record 48 of Set 15 | karasburg
# Processing Record 49 of Set 15 | shakawe
# Processing Record 50 of Set 15 | severodvinsk
# Processing Record 1 of Set 16 | mangit
# Processing Record 2 of Set 16 | champerico
# Processing Record 3 of Set 16 | kalevala
# Processing Record 4 of Set 16 | monrovia
# Processing Record 5 of Set 16 | terrace
# Processing Record 6 of Set 16 | port-gentil
# Processing Record 7 of Set 16 | fort myers beach
# Processing Record 8 of Set 16 | otane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                     Vaini      TO -21.2000 -175.2000     71.76       100
# 1                  Havelock      US  34.8791  -76.9013     77.95        92
# 2                 Mount Isa      AU -20.7333  139.5000     80.37        26
# 3  Santa Maria Da Boa Vista      BR  -8.8078  -39.8256     69.91        80
# 4                 Busselton      AU -33.6500  115.3333     61.05        56
# 5              Puerto Ayora      EC  -0.7393  -90.3518     71.55        98
# 6                  Saldanha      ZA -33.0117   17.9442     68.05        38
# 7                  Akureyri      IS  65.6835  -18.0878     44.53        76
# 8               Henties Bay      NA -22.1160   14.2845     66.87        49
# 9                   Qaanaaq      GL  77.4840  -69.3632     38.16        72
#
#    Cloudiness  Wind Speed Current Description                 Date
# 0          90        5.75          light rain  2021-06-07 04:46:38
# 1           1        1.99           clear sky  2021-06-07 04:46:39
# 2           0        8.05           clear sky  2021-06-07 04:37:54
# 3          90       11.01     overcast clouds  2021-06-07 04:37:55
# 4          60        9.15       broken clouds  2021-06-07 04:37:55
# 5          30        1.01    scattered clouds  2021-06-07 04:46:39
# 6          16       27.85          few clouds  2021-06-07 04:46:40
# 7           0        3.44           clear sky  2021-06-07 04:46:40
# 8           0        9.89           clear sky  2021-06-07 04:46:40
# 9          36        5.99    scattered clouds  2021-06-07 04:46:41

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
